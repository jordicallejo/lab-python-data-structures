# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %% [markdown]
# ## Solution
#
# La lista `products` define el catálogo; `inventory` relaciona cada producto con su cantidad; `customer_orders` guarda tres productos distintos; `order_status` es una tupla con el total y el porcentaje sobre los cinco productos del catálogo.
#
# **Interpretación del paso 9:** el enunciado pide restar una unidad de *cada producto*, por lo que se actualizan las cinco entradas del inventario. Para esta operación se solicitan cantidades enteras de al menos 1. En una tienda real se descontarían únicamente los productos pedidos; aquí se sigue literalmente el enunciado.
#
# **Prueba guardada:** cantidades 10, 8, 6, 4 y 2; pedido de t-shirt, mug y book. Resultado esperado: 3 productos, 60.0%; inventario final 9, 7, 5, 3 y 1.

# %%
# Steps 1-3: create the product list and collect inventory quantities.
products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {}

for product in products:
    while True:
        try:
            quantity = int(input(f"Enter available quantity for {product}: "))
            if quantity < 1:
                print("Enter an integer of at least 1 (step 9 subtracts one from every product).")
                continue
            inventory[product] = quantity
            break
        except ValueError:
            print("Please enter a whole number.")

print("Initial inventory:", inventory)
# Out:
# Initial inventory: {'t-shirt': 10, 'mug': 8, 'hat': 6, 'book': 4, 'keychain': 2}

# %%
# Steps 4-6: collect three different products from the catalogue.
customer_orders = set()
print("Available products:", products)

while len(customer_orders) < 3:
    product = input(f"Enter product {len(customer_orders) + 1} of 3: ").strip().lower()
    if product not in products:
        print("Please choose a product from the list.")
    elif product in customer_orders:
        print("That product is already in the order. Choose another one.")
    else:
        customer_orders.add(product)

print("Customer orders:", customer_orders)
# Out:
# Available products: ['t-shirt', 'mug', 'hat', 'book', 'keychain']
# Customer orders: {'t-shirt', 'book', 'mug'}

# %%
# Steps 7-8: store the count and catalogue percentage in a tuple.
total_products_ordered = len(customer_orders)
percentage_ordered = total_products_ordered / len(products) * 100
order_status = (total_products_ordered, percentage_ordered)

print("Order Statistics:")
print(f"Total Products Ordered: {order_status[0]}")
print(f"Percentage of Products Ordered: {order_status[1]:.1f}%")
# Out:
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 60.0%

# %%
# Steps 9-10: subtract one from EVERY product, as stated in the exercise.
for product in inventory:
    inventory[product] -= 1

print("Updated inventory:")
for product, quantity in inventory.items():
    print(f"{product}: {quantity}")
# Out:
# Updated inventory:
# t-shirt: 9
# mug: 7
# hat: 5
# book: 3
# keychain: 1
